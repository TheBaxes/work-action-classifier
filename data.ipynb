# %% [markdown]
# # Data

# %%
import tensorflow as tf
tf.enable_eager_execution()

# %%
import data

# %load_ext autoreload
# %autoreload 2

# %%
params = {'batch_size': 128, 'shuffle_buffer': 512, 'image_size': 32}

# %%
sources = data.find_sources('dataset')

# %%
sources[:10]
# Out:
# [('dataset/train/00012/00050_00013.jpg', 12),
#  ('dataset/train/00025/00047_00015.jpg', 25),
#  ('dataset/train/00005/00055_00010.jpg', 5),
#  ('dataset/train/00004/00048_00017.jpg', 4),
#  ('dataset/train/00004/00047_00017.jpg', 4),
#  ('dataset/train/00025/00008_00025.jpg', 25),
#  ('dataset/train/00002/00048_00010.jpg', 2),
#  ('dataset/train/00021/00005_00007.jpg', 21),
#  ('dataset/train/00010/00044_00025.jpg', 10),
#  ('dataset/train/00033/00019_00004.jpg', 33)]

# %%
features, labels = data.input_fn(sources, False, params)

# %%
features
# Out:
# {'image': <tf.Tensor: id=541, shape=(128, 32, 32, 3), dtype=float32, numpy=
#  array([[[[0.20784314, 0.2       , 0.28235295],
#           [0.23700982, 0.23186275, 0.27573532],
#           [0.13627452, 0.13088235, 0.12598039],
#           ...,
#           [0.15318628, 0.15318628, 0.18455882],
#           [0.14362745, 0.14803922, 0.17794117],
#           [0.12156863, 0.13333334, 0.16078432]],
#
#          [[0.20269608, 0.19607843, 0.2747549 ],
#           [0.24169733, 0.23655026, 0.2804228 ],
#           [0.14341299, 0.13802083, 0.13556986],
#           ...,
#           [0.17731312, 0.17731312, 0.20868567],
#           [0.14564951, 0.15006128, 0.17996325],
#           [0.13308825, 0.14485295, 0.17230393]],
#
#          [[0.19754902, 0.19362745, 0.2642157 ],
#           [0.24491422, 0.23976716, 0.28363973],
#           [0.15692402, 0.15153188, 0.15214461],
#           ...,
#           [0.16761643, 0.16761643, 0.19898897],
#           [0.13903187, 0.14344363, 0.1733456 ],
# ...

# %%
labels
# Out:
# <tf.Tensor: id=542, shape=(128,), dtype=int32, numpy=
# array([12, 25,  5,  4,  4, 25,  2, 21, 10, 33, 11, 17, 38, 12, 38,  9, 11,
#        28,  2, 13,  8, 35, 31, 35, 12, 12, 39, 10, 18, 31,  1, 13, 26,  3,
#        35, 35,  7,  2, 39, 25,  4, 18, 13,  7,  5,  4, 39, 26, 13, 10, 25,
#        14, 23,  1, 25, 38, 32,  0, 30, 28,  4, 35,  4, 25, 10, 26,  1, 22,
#        12, 12,  7,  5, 38,  1,  5, 17, 13, 15, 12,  6, 10, 24, 10,  4, 32,
#         4, 31, 12, 20, 13, 22, 25,  3, 13, 20,  2, 12,  2, 18,  2,  8, 17,
#        11, 12, 15, 22, 22, 25, 30, 17, 33, 10,  1, 38, 12, 16, 38,  2,  1,
#         9, 31, 36, 35, 13,  8,  8, 29,  1], dtype=int32)>
